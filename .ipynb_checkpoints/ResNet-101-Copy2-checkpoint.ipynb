# %%
from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from mpl_toolkits.axes_grid1 import ImageGrid
plt.ion()
from torch.utils.data.sampler import SubsetRandomSampler
#%matplotlib inline

# %%
# Data augmentation and normalization for training 
# Just normalization for validation

data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224), 
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406],[0.229, 0.224, 0.225])
    ]),
    'val':transforms.Compose([
        transforms.Resize(180),
        transforms.CenterCrop(180),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],[0.229, 0.224, 0.225])
    ])    
}

# %%
#image_dataset Attributes:
# classes (list): List of the class names.
# class_to_idx (dict): Dict with items (class_name, class_index).
# imgs (list): List of (image path, class_index) tuples
            
#data_dir='/home/mnt/jupyter_dir/hymenoptera_data'
data_dir='/home/mnt/jupyter_dir/imagewoof'
#data_dir='/home/mnt/jupyter_dir/tiny-imagenet-200'
#data_dir='/home/mnt/jupyter_dir/stanford-cars'
image_datasets = { x: datasets.ImageFolder(os.path.join(data_dir, x), 
                        data_transforms[x]) for x in ['train', 'val'] }

image_datasets
# Out:
# {'train': Dataset ImageFolder
#      Number of datapoints: 12454
#      Root location: /home/mnt/jupyter_dir/imagewoof/train,
#  'val': Dataset ImageFolder
#      Number of datapoints: 500
#      Root location: /home/mnt/jupyter_dir/imagewoof/val}

# %%
dataloaders= {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=16, 
                                             shuffle=True, num_workers=0)
              for x in ['train', 'val'] }
dataset_sizes = {x: len(image_datasets[x]) for x in ['train','val']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
'''train_size = int(0.8 * dataset_sizes['train'])
test_size = 12454- train_size
print(train_size,test_size)
train, test = torch.utils.data.random_split(image_datasets['train'], [train_size, test_size])   
image_datasets['test']=test
image_datasets['train']=train

dataloaders_train = torch.utils.data.DataLoader(train, batch_size=16, 
                                             shuffle=True, num_workers=4)
dataloaders_test = torch.utils.data.DataLoader(test, batch_size=16, 
                                             shuffle=True, num_workers=4)
'''
# Out:
# "train_size = int(0.8 * dataset_sizes['train'])\ntest_size = 12454- train_size\nprint(train_size,test_size)\ntrain, test = torch.utils.data.random_split(image_datasets['train'], [train_size, test_size])   \nimage_datasets['test']=test\nimage_datasets['train']=train\n\ndataloaders_train = torch.utils.data.DataLoader(train, batch_size=16, \n                                             shuffle=True, num_workers=4)\ndataloaders_test = torch.utils.data.DataLoader(test, batch_size=16, \n                                             shuffle=True, num_workers=4)\n"

# %%
# Get a batch of training data
inputs, classes = next(iter(dataloaders['val']))

inputs.size()
# Out:
# torch.Size([16, 3, 180, 180])

# %%
class_names
# Out:
# ['n02086240',
#  'n02087394',
#  'n02088364',
#  'n02089973',
#  'n02093754',
#  'n02096294',
#  'n02099601',
#  'n02105641',
#  'n02111889',
#  'n02115641']

# %%
def imshow(axis, inp):
    """Denormalize and show"""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    axis.imshow((inp * 255).astype(np.uint8))

# %%
train = dataloaders['train']
img, label = next(iter(train))
print(img.size(), label.size())
fig = plt.figure(1, figsize=(16, 4))
grid = ImageGrid(fig, 111, nrows_ncols=(2, 8), axes_pad=0.05)    
for i in range(img.size()[0]):
    ax = grid[i]
    imshow(ax, img[i])
# Out:
# torch.Size([16, 3, 224, 224]) torch.Size([16])

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25, flag_Load=True):
    
    since= time.time()
    
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    
    
    
    for epoch in range(num_epochs-1):
        print('Epoch {}/{}'.format(epoch, num_epochs-1))
        print('-'* 10)
        
        if flag_Load==True:
            print('Loading model from disk')
            flag_Load=False
            checkpoint = torch.load('/home/mnt/jupyter_dir/saved_model_dog/resnet101_28.pth.tar')
            model.load_state_dict(checkpoint['model_state_dict'])
            optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
            epoch = checkpoint['epoch']
            loss = checkpoint['loss']
            best_acc = checkpoint['best_prec1']
            
        # Each epoch has a training and validation phase
        for phase in ['train','val']:
            
            if phase == 'train':
                
                scheduler.step()
                model.train() # set model to training mode
            else:
                
                model.eval() # Set model to evaluate mode
            
            running_loss = 0.0
            running_corrects = 0
            
            #Iterate over data
            for inputs, labels in dataloaders[phase]:
                
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                #zero the parameter gradients
                optimizer.zero_grad()
                
                #forward
                # track history if only in train
                
                with torch.set_grad_enabled(phase=='train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs,1)
                    loss = criterion(outputs, labels)
                    
                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()
                # statistics
                running_loss += loss.item()*inputs.size(0)
                running_corrects += torch.sum(preds==labels.data)
                
            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
            
            print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))
            
            if phase == 'val' and epoch_acc> best_acc:
                print('input shape for validation', inputs.shape)
                best_acc= epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
        
            print()
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'loss': loss,
                'best_prec1': best_acc}, '/home/mnt/jupyter_dir/saved_model_dog/resnet101_'+str(epoch)+'.pth.tar')
        
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed//60, time_elapsed % 60))
    print('Best val Acc : {:4f}'.format(best_acc))
    
    #save entire model
    torch.save(model,'/home/mnt/jupyter_dir/saved_model_dog/resnet101.pth.tar')
    
    # load best weights
    model.load_state_dict(best_model_wts)
    
    return model

# %%
model_conv = torchvision.models.resnet101(pretrained=True)
for param in model_conv.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
num_ftrs = model_conv.fc.in_features
model_conv.fc = nn.Linear(num_ftrs, 10)

model_conv = model_conv.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_conv.fc.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_conv, step_size=7, gamma=0.1)

# %%
model_conv = train_model(model_conv, criterion, optimizer_conv,
                         exp_lr_scheduler, num_epochs=30, flag_Load=False)
# Out:
# Epoch 0/29
# ----------
# train Loss: 0.5896 Acc: 0.8340
#
# val Loss: 0.2669 Acc: 0.9080
# input shape for validation torch.Size([4, 3, 180, 180])
#
# Epoch 1/29
# ----------
# train Loss: 0.3938 Acc: 0.8731
#
# val Loss: 0.2436 Acc: 0.9120
# input shape for validation torch.Size([4, 3, 180, 180])
#
# Epoch 2/29
# ----------
# train Loss: 0.3742 Acc: 0.8799
#
# val Loss: 0.2727 Acc: 0.9180
# input shape for validation torch.Size([4, 3, 180, 180])
#
# Epoch 3/29
# ----------
# train Loss: 0.3656 Acc: 0.8786
#
# val Loss: 0.2845 Acc: 0.9140
#
# Epoch 4/29
# ----------
# train Loss: 0.3596 Acc: 0.8790
#
# val Loss: 0.2532 Acc: 0.9180
#
# Epoch 5/29
# ----------
# train Loss: 0.3629 Acc: 0.8809
#
# val Loss: 0.2738 Acc: 0.9160
#
# Epoch 6/29
# ----------
# train Loss: 0.3406 Acc: 0.8894
#
# val Loss: 0.2731 Acc: 0.9180
#
# Epoch 7/29
# ----------
# train Loss: 0.3478 Acc: 0.8838
#
# val Loss: 0.2609 Acc: 0.9180
#
# Epoch 8/29
# ----------
# train Loss: 0.3267 Acc: 0.8916
#
# val Loss: 0.2467 Acc: 0.9200
# input shape for validation torch.Size([4, 3, 180, 180])
#
# Epoch 9/29
# ----------
# train Loss: 0.3444 Acc: 0.8861
#
# val Loss: 0.2330 Acc: 0.9180
#
# Epoch 10/29
# ----------
# train Loss: 0.3244 Acc: 0.8922
#
# val Loss: 0.2620 Acc: 0.9200
#
# Epoch 11/29
# ----------
# train Loss: 0.3393 Acc: 0.8862
#
# val Loss: 0.2639 Acc: 0.9200
#
# Epoch 12/29
# ----------
# train Loss: 0.3444 Acc: 0.8885
#
# val Loss: 0.2508 Acc: 0.9240
# input shape for validation torch.Size([4, 3, 180, 180])
#
# Epoch 13/29
# ----------
# train Loss: 0.3410 Acc: 0.8877
#
# val Loss: 0.2729 Acc: 0.9200
#
# Epoch 14/29
# ----------
# train Loss: 0.3338 Acc: 0.8891
#
# val Loss: 0.2522 Acc: 0.9180
#
# Epoch 15/29
# ----------
# train Loss: 0.3389 Acc: 0.8857
#
# val Loss: 0.2662 Acc: 0.9180
#
# Epoch 16/29
# ----------
# train Loss: 0.3424 Acc: 0.8828
#
# val Loss: 0.2502 Acc: 0.9200
#
# Epoch 17/29
# ----------
# train Loss: 0.3395 Acc: 0.8901
#
# val Loss: 0.2449 Acc: 0.9280
# input shape for validation torch.Size([4, 3, 180, 180])
#
# Epoch 18/29
# ----------
# train Loss: 0.3378 Acc: 0.8879
#
# val Loss: 0.2609 Acc: 0.9200
#
# Epoch 19/29
# ----------
# train Loss: 0.3372 Acc: 0.8877
#
# val Loss: 0.2548 Acc: 0.9200
#
# Epoch 20/29
# ----------
# train Loss: 0.3392 Acc: 0.8857
#
# val Loss: 0.2761 Acc: 0.9180
#
# Epoch 21/29
# ----------
# train Loss: 0.3382 Acc: 0.8884
#
# val Loss: 0.2418 Acc: 0.9180
#
# Epoch 22/29
# ----------
# train Loss: 0.3381 Acc: 0.8872
#
# val Loss: 0.2587 Acc: 0.9080
#
# Epoch 23/29
# ----------
# train Loss: 0.3329 Acc: 0.8910
#
# val Loss: 0.2587 Acc: 0.9180
#
# Epoch 24/29
# ----------
# train Loss: 0.3418 Acc: 0.8879
#
# val Loss: 0.2410 Acc: 0.9160
#
# Epoch 25/29
# ----------
# train Loss: 0.3361 Acc: 0.8895
#
# val Loss: 0.2590 Acc: 0.9160
#
# Epoch 26/29
# ----------
# train Loss: 0.3285 Acc: 0.8898
#
# val Loss: 0.2457 Acc: 0.9260
#
# Epoch 27/29
# ----------
# train Loss: 0.3296 Acc: 0.8881
#
# val Loss: 0.2547 Acc: 0.9220
#
# Epoch 28/29
# ----------
# train Loss: 0.3388 Acc: 0.8873
#
# val Loss: 0.2607 Acc: 0.9180
#
# Training complete in 58m 46s
# Best val Acc : 0.928000

# %%
#model_conv

# %%
from PIL import Image
def image_loader(loader, image_name):
    image = Image.open(image_name)
    image = loader(image).float()
    image = torch.tensor(image, requires_grad=False)
    image = image.unsqueeze(0)
    return image

data_transforms = transforms.Compose([
    transforms.Resize(100),
    transforms.CenterCrop(100),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229, 0.224, 0.225])
])


inputs = image_loader(data_transforms,'/home/mnt/jupyter_dir/imagenette/test1s.jpg')
print(inputs.shape)
corrects=0
model_conv.eval()
with torch.no_grad():    
    #inputs, classes = next(iter(dataloaders['val']))
    inputs = inputs.to(device)
    #classes = classes.to(device)
    logits = model_conv(inputs)
    _, pred=torch.max(logits,1)
    #corrects = torch.sum(pred==classes)
# Out:
# torch.Size([1, 3, 100, 100])
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   """

# %%
pred
# Out:
# tensor([6], device='cuda:0')

# %%
logits
# Out:
# tensor([[-4.4188, -2.4998, -1.1672,  3.6040, -2.4621, -2.4955,  7.7907,  4.6317,
#          -3.9088,  0.1829]], device='cuda:0')

# %%
# transformer for validation image
data_transforms2 = {
    'val':transforms.Compose([
        transforms.Resize(180),
        transforms.CenterCrop(180),
        transforms.ToTensor(),
        transforms.Normalize([0.485,0.456,0.406],[0.229, 0.224, 0.225])
    ])    
}

#load folders
image_datasets = { x: datasets.ImageFolder(os.path.join(data_dir, x), 
                        data_transforms2[x]) for x in ['val'] }
print(image_datasets)

#dataloader from folders
dataloaders2= {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=16, 
                                             shuffle=True, num_workers=0)
              for x in ['val'] }
dataset_sizes = {x: len(image_datasets[x]) for x in ['val']}
print(dataset_sizes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-776cd7f9ce47> in <module>
#       1 # transformer for validation image
#       2 data_transforms2 = {
# ----> 3     'val':transforms.Compose([
#       4         transforms.Resize(180),
#       5         transforms.CenterCrop(180),
#
# NameError: name 'transforms' is not defined

# %%
# Get a batch of training data
inputs, classes = next(iter(dataloaders['val']))

inputs.shape
# Out:
# torch.Size([16, 3, 224, 224])

# %%
since= time.time()
model_conv.eval()
running_loss = 0.0
running_corrects = 0
#Iterate over data
for inputs, labels in dataloaders['val']:
    #print(inputs.shape)
    inputs = inputs.to(device)
    labels = labels.to(device)
    outputs = model_conv(inputs)
    _, preds = torch.max(outputs,1)
    loss = criterion(outputs, labels)
    # statistics
    running_loss += loss.item()*inputs.size(0)
    running_corrects += torch.sum(preds==labels.data)
    
    epoch_loss = running_loss / dataset_sizes['val']
    epoch_acc = running_corrects.double() / dataset_sizes['val']
    
    print('{} Loss: {:.4f} Acc: {:.4f}'.format('val', epoch_loss, epoch_acc))
    time_elapsed = time.time() - since
    print('Batch Evaluation completed in {:.0f}m {:.0f}s'.format(time_elapsed//60, time_elapsed % 60))
time_elapsed = time.time() - since
print('Validation completed in {:.0f}m {:.0f}s'.format(time_elapsed//60, time_elapsed % 60))
# Out:
# val Loss: 0.0747 Acc: 0.0000
# Batch Evaluation completed in 0m 0s
# val Loss: 0.1489 Acc: 0.0040
# Batch Evaluation completed in 0m 0s
# val Loss: 0.2205 Acc: 0.0060
# Batch Evaluation completed in 0m 1s
# val Loss: 0.2952 Acc: 0.0080
# Batch Evaluation completed in 0m 1s
# val Loss: 0.3707 Acc: 0.0100
# Batch Evaluation completed in 0m 1s
# val Loss: 0.4444 Acc: 0.0140
# Batch Evaluation completed in 0m 1s
# val Loss: 0.5162 Acc: 0.0180
# Batch Evaluation completed in 0m 1s
# val Loss: 0.5891 Acc: 0.0220
# Batch Evaluation completed in 0m 1s
# val Loss: 0.6634 Acc: 0.0220
# Batch Evaluation completed in 0m 2s
# val Loss: 0.7358 Acc: 0.0280
# Batch Evaluation completed in 0m 2s
# val Loss: 0.8138 Acc: 0.0320
# Batch Evaluation completed in 0m 2s
# val Loss: 0.8881 Acc: 0.0320
# Batch Evaluation completed in 0m 2s
# val Loss: 0.9619 Acc: 0.0380
# Batch Evaluation completed in 0m 2s
# val Loss: 1.0358 Acc: 0.0380
# Batch Evaluation completed in 0m 2s
# val Loss: 1.1090 Acc: 0.0480
# Batch Evaluation completed in 0m 3s
# val Loss: 1.1845 Acc: 0.0500
# Batch Evaluation completed in 0m 3s
# val Loss: 1.2562 Acc: 0.0580
# Batch Evaluation completed in 0m 3s
# val Loss: 1.3324 Acc: 0.0580
# Batch Evaluation completed in 0m 3s
# val Loss: 1.4047 Acc: 0.0620
# Batch Evaluation completed in 0m 3s
# val Loss: 1.4794 Acc: 0.0640
# Batch Evaluation completed in 0m 4s
# val Loss: 1.5514 Acc: 0.0660
# Batch Evaluation completed in 0m 4s
# val Loss: 1.6290 Acc: 0.0680
# Batch Evaluation completed in 0m 4s
# val Loss: 1.7019 Acc: 0.0680
# Batch Evaluation completed in 0m 4s
# val Loss: 1.7744 Acc: 0.0720
# Batch Evaluation completed in 0m 4s
# val Loss: 1.8503 Acc: 0.0720
# Batch Evaluation completed in 0m 4s
# val Loss: 1.9251 Acc: 0.0720
# Batch Evaluation completed in 0m 5s
# val Loss: 2.0002 Acc: 0.0740
# Batch Evaluation completed in 0m 5s
# val Loss: 2.0760 Acc: 0.0760
# Batch Evaluation completed in 0m 5s
# val Loss: 2.1531 Acc: 0.0780
# Batch Evaluation completed in 0m 5s
# val Loss: 2.2274 Acc: 0.0820
# Batch Evaluation completed in 0m 5s
# val Loss: 2.3005 Acc: 0.0860
# Batch Evaluation completed in 0m 5s
# val Loss: 2.3170 Acc: 0.0900
# Batch Evaluation completed in 0m 5s
# Validation completed in 0m 5s
